# %% [markdown]
# <a href="https://colab.research.google.com/github/geraldalivia/Satellite-Image-Classification/blob/main/notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Proyek Klasifikasi Gambar: Satellite Image Classification
# - **Nama:** Geralda Livia Nugraha
# - **Email:** geraldaliviaa93@gmail.com || mc299d5x1168@student.devacademy.id
# - **ID Dicoding:** alddar (MC299D5X1168)

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
# Intall Depedencies
# !pip install tensorflowjs
# !pip freeze > requirements.txt
# Out:
# Requirement already satisfied: tensorflowjs in /usr/local/lib/python3.11/dist-packages (4.22.0)
# Requirement already satisfied: flax>=0.7.2 in /usr/local/lib/python3.11/dist-packages (from tensorflowjs) (0.10.6)
# Requirement already satisfied: importlib_resources>=5.9.0 in /usr/local/lib/python3.11/dist-packages (from tensorflowjs) (6.5.2)
# Requirement already satisfied: jax>=0.4.13 in /usr/local/lib/python3.11/dist-packages (from tensorflowjs) (0.5.2)
# Requirement already satisfied: jaxlib>=0.4.13 in /usr/local/lib/python3.11/dist-packages (from tensorflowjs) (0.5.1)
# Requirement already satisfied: tensorflow<3,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from tensorflowjs) (2.18.0)
# Requirement already satisfied: tf-keras>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from tensorflowjs) (2.18.0)
# Requirement already satisfied: tensorflow-decision-forests>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflowjs) (1.11.0)
# Requirement already satisfied: six<2,>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from tensorflowjs) (1.17.0)
# Requirement already satisfied: tensorflow-hub>=0.16.1 in /usr/local/lib/python3.11/dist-packages (from tensorflowjs) (0.16.1)
# Requirement already satisfied: packaging~=23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflowjs) (23.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from flax>=0.7.2->tensorflowjs) (2.0.2)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.11/dist-packages (from flax>=0.7.2->tensorflowjs) (1.1.0)
# Requirement already satisfied: optax in /usr/local/lib/python3.11/dist-packages (from flax>=0.7.2->tensorflowjs) (0.2.4)
# Requirement already satisfied: orbax-checkpoint in /usr/local/lib/python3.11/dist-packages (from flax>=0.7.2->tensorflowjs) (0.11.13)
# Requirement already satisfied: tensorstore in /usr/local/lib/python3.11/dist-packages (from flax>=0.7.2->tensorflowjs) (0.1.74)
# Requirement already satisfied: rich>=11.1 in /usr/local/lib/python3.11/dist-packages (from flax>=0.7.2->tensorflowjs) (13.9.4)
# Requirement already satisfied: typing_extensions>=4.2 in /usr/local/lib/python3.11/dist-packages (from flax>=0.7.2->tensorflowjs) (4.13.2)
# Requirement already satisfied: PyYAML>=5.4.1 in /usr/local/lib/python3.11/dist-packages (from flax>=0.7.2->tensorflowjs) (6.0.2)
# Requirement already satisfied: treescope>=0.1.7 in /usr/local/lib/python3.11/dist-packages (from flax>=0.7.2->tensorflowjs) (0.1.9)
# Requirement already satisfied: ml_dtypes>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from jax>=0.4.13->tensorflowjs) (0.4.1)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.11/dist-packages (from jax>=0.4.13->tensorflowjs) (3.4.0)
# Requirement already satisfied: scipy>=1.11.1 in /usr/local/lib/python3.11/dist-packages (from jax>=0.4.13->tensorflowjs) (1.15.3)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (18.1.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (5.29.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (75.2.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (3.1.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (1.71.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (3.8.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (3.13.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (0.37.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from tensorflow-decision-forests>=1.5.0->tensorflowjs) (2.2.2)
# Requirement already satisfied: wheel in /usr/local/lib/python3.11/dist-packages (from tensorflow-decision-forests>=1.5.0->tensorflowjs) (0.45.1)
# Requirement already satisfied: wurlitzer in /usr/local/lib/python3.11/dist-packages (from tensorflow-decision-forests>=1.5.0->tensorflowjs) (3.1.1)
# Requirement already satisfied: ydf in /usr/local/lib/python3.11/dist-packages (from tensorflow-decision-forests>=1.5.0->tensorflowjs) (0.12.0)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow<3,>=2.13.0->tensorflowjs) (0.0.9)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow<3,>=2.13.0->tensorflowjs) (0.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow<3,>=2.13.0->tensorflowjs) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow<3,>=2.13.0->tensorflowjs) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow<3,>=2.13.0->tensorflowjs) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow<3,>=2.13.0->tensorflowjs) (2025.4.26)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=11.1->flax>=0.7.2->tensorflowjs) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=11.1->flax>=0.7.2->tensorflowjs) (2.19.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow<3,>=2.13.0->tensorflowjs) (3.8)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow<3,>=2.13.0->tensorflowjs) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow<3,>=2.13.0->tensorflowjs) (3.1.3)
# Requirement already satisfied: chex>=0.1.87 in /usr/local/lib/python3.11/dist-packages (from optax->flax>=0.7.2->tensorflowjs) (0.1.89)
# Requirement already satisfied: etils[epy] in /usr/local/lib/python3.11/dist-packages (from optax->flax>=0.7.2->tensorflowjs) (1.12.2)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.11/dist-packages (from orbax-checkpoint->flax>=0.7.2->tensorflowjs) (1.6.0)
# Requirement already satisfied: humanize in /usr/local/lib/python3.11/dist-packages (from orbax-checkpoint->flax>=0.7.2->tensorflowjs) (4.12.3)
# Requirement already satisfied: simplejson>=3.16.0 in /usr/local/lib/python3.11/dist-packages (from orbax-checkpoint->flax>=0.7.2->tensorflowjs) (3.20.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->tensorflow-decision-forests>=1.5.0->tensorflowjs) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->tensorflow-decision-forests>=1.5.0->tensorflowjs) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->tensorflow-decision-forests>=1.5.0->tensorflowjs) (2025.2)
# Requirement already satisfied: toolz>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from chex>=0.1.87->optax->flax>=0.7.2->tensorflowjs) (0.12.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1->flax>=0.7.2->tensorflowjs) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow<3,>=2.13.0->tensorflowjs) (3.0.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from etils[epath,epy]->orbax-checkpoint->flax>=0.7.2->tensorflowjs) (2025.3.2)
# Requirement already satisfied: zipp in /usr/local/lib/python3.11/dist-packages (from etils[epath,epy]->orbax-checkpoint->flax>=0.7.2->tensorflowjs) (3.21.0)

# %%
# Library
import os
import shutil
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import random
from pathlib import Path

# Load Data dan Akses ke Drive
from google.colab import drive

# Processing Data
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing import image

# Build Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Training Model
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# Save Model
import tensorflow as tf
import tensorflowjs as tfjs
# Out:
# <p style="margin:0px;">🌲 Try <a href="https://ydf.readthedocs.io/en/latest/" target="_blank">YDF</a>, the successor of
#     <a href="https://www.tensorflow.org/decision_forests" target="_blank">TensorFlow
#         Decision Forests</a> using the same algorithms but with more features and faster
#     training!
# </p>
# <div style="display: flex; flex-wrap: wrap; margin:5px;max-width: 880px;">
#     <div style="flex: 1; border-radius: 10px; background-color: F0F0F0; padding: 5px;">
#         <p
#             style="font-weight: bold; margin:0px;text-align: center;border-bottom: 1px solid #C0C0C0;margin-bottom: 4px;">
#             Old code</p>
#         <pre style="overflow-wrap: anywhere; overflow: auto; margin:0px;font-size: 9pt;">
# import tensorflow_decision_forests as tfdf
#
# tf_ds = tfdf.keras.pd_dataframe_to_tf_dataset(ds, label="l")
# model = tfdf.keras.RandomForestModel(label="l")
# model.fit(tf_ds)
# </pre>
#     </div>
#     <div style="width: 5px;"></div>
#     <div style="flex: 1; border-radius: 10px; background-color: F0F0F0; padding: 5px;">
#         <p
#             style="font-weight: bold; margin:0px;text-align: center;border-bottom: 1px solid #C0C0C0;margin-bottom: 4px;">
#             New code</p>
#         <pre style="overflow-wrap: anywhere; overflow: auto; margin:0px;font-size: 9pt;">
# import ydf
#
# model = ydf.RandomForestLearner(label="l").train(ds)
# </pre>
#     </div>
# </div>
# <p style="margin:0px;font-size: 9pt;">(Learn more in the <a
#         href="https://ydf.readthedocs.io/en/latest/tutorial/migrating_to_ydf/" target="_blank">migration
#         guide</a>)</p>

# %%
# Untuk requirement.txt
from google.colab import files
files.download('requirements.txt')

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# ### Data Loading

# %%
# Mounting GDrive
drive.mount('/content/drive')

# Load dataset .zip
# !unzip "/content/drive/MyDrive/Submission/Deep Learning/Image Classification/Dataset/Satellite.zip" -d "/content/satellite_dataset"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/satellite_dataset/data/cloudy/train_23566.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_23598.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_23608.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_23634.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_23636.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_23646.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_2366.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_23664.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_23706.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_2380.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_23805.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_23806.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_23826.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_23843.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_23877.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_23884.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_23953.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_2396.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_23978.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_23979.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_23980.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_23981.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_24001.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_24013.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_24031.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_24070.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_24080.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_24094.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_24114.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_24139.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_24164.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_24192.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_24212.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_24237.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_2424.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_24249.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_24270.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_24280.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_24285.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_24299.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_24301.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_24303.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_2431.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_24328.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_24350.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_24390.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_24396.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_24443.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_24472.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_24490.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_24521.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_24636.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_24640.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_24649.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_24693.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_24724.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_24777.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_24829.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_24891.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_24897.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_24917.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_24936.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_24945.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_24989.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_24991.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_25029.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_25033.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_25041.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_25106.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_25109.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_25113.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_25127.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_25138.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_2516.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_25176.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_25207.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_25219.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_25327.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_25337.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_25343.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_25389.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_25399.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_2550.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_25557.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_25595.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_25602.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_2562.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_25626.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_25647.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_25659.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_25747.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_25815.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_25818.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_25827.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_25843.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_25851.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_25953.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_25971.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_26.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_26015.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_26084.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_26102.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_26108.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_26159.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_26216.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_26226.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_2636.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_26411.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_26416.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_26436.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_26443.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_26456.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_26460.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_2648.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_26485.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_26512.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_26528.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_26540.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_26541.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_2655.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_26562.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_26564.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_26572.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_26600.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_2664.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_26643.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_26658.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_26673.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_26722.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_26814.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_26882.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_26892.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_26916.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_26957.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_2699.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_27005.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_27010.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_27120.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_27202.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_27204.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_27223.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_27239.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_27254.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_27302.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_27355.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_27379.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_27397.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_27399.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_27446.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_27460.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_27474.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_27527.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_27545.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_27556.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_27602.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_27660.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_2770.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_27734.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_2778.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_27788.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_2781.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_27810.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_27884.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_27921.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_27945.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_2796.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_28057.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_28072.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_28089.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_28182.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_28197.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_28215.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_28242.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_28244.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_28284.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_28292.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_28318.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_28329.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_284.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_2841.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_28432.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_28444.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_28454.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_28463.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_28485.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_28488.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_28511.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_28518.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_28522.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_28534.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_28537.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_28555.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_28575.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_28680.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_28684.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_28686.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_28743.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_28762.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_28765.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_28808.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_28831.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_28832.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_28851.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_28903.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_28919.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_28923.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_28936.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_28974.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_28991.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_2900.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_29002.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_29014.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_29016.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_2904.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_29061.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_29080.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_29109.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_2911.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_29151.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_29162.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_29171.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_29187.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_29201.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_29242.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_29245.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_29278.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_29292.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_29353.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_29355.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_29368.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_29391.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_29412.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_29424.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_29504.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_29523.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_29528.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_29540.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_29550.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_2965.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_29653.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_29667.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_29680.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_29732.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_29733.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_29781.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_29808.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_29833.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_29842.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_29850.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_29861.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_29881.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_29917.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_29956.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_29996.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_30001.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_30056.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_30083.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_3014.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_30155.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_30211.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_30234.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_30244.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_30255.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_30262.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_30274.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_30308.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_30311.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_3036.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_30364.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_30389.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_30403.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_30408.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_30437.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_30534.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_30586.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_30614.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_30623.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_30649.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_30686.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_30696.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_30702.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_30724.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_30730.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_30746.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_30762.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_30764.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_3078.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_30792.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_30798.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_30809.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_30811.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_30828.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_30838.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_30862.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_30882.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_30902.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_30946.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_30949.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_3096.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_3098.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_3099.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_31030.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_31129.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_31184.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_3119.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_31197.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_31228.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_31239.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_31242.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_3125.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_31251.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_3126.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_3128.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_31296.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_31339.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_31358.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_3136.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_31365.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_31368.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_31369.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_31384.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_31387.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_31446.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_31527.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_31530.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_31588.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_31600.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_3165.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_31651.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_31713.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_31756.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_3176.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_31783.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_31822.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_31869.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_31870.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_31887.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_31892.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_31909.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_31939.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_31951.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_31954.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_31979.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_32009.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_32011.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_32116.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_32139.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_32228.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_32257.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_32278.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_32283.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_32309.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_32320.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_32330.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_32375.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_32385.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_32408.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_32431.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_32433.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_32513.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_32526.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_32613.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_32617.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_32670.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_32698.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_32704.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_32717.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_3278.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_32799.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_32802.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_32819.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_32828.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_32830.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_32846.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_32869.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_32882.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_32961.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_3297.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_32973.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_32993.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_33140.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_33260.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_33269.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_3327.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_33296.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_33299.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_33313.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_33341.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_33425.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_33463.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_33466.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_33481.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_33510.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_33520.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_33523.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_33524.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_33560.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_33590.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_33597.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_33639.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_3366.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_3368.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_33758.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_33880.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_33928.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_33933.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_3395.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_33962.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_33973.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_34058.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_3406.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_34079.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_34082.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_34125.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_34163.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_34175.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_34176.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_34205.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_34208.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_34216.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_34249.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_343.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_34303.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_34355.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_34391.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_34481.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_34498.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_34507.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_34534.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_34585.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_34669.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_34671.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_34681.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_34728.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_3473.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_34754.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_34770.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_34772.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_34789.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_34803.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_34831.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_34841.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_34888.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_34895.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_34936.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_34951.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_35105.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_3512.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_35153.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_35179.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_35193.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_352.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_35205.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_35275.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_35367.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_35399.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_3542.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_35426.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_35457.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_35475.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_35495.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_35499.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_35506.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_35508.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_35525.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_35543.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_35551.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_35665.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_35753.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_35773.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_35811.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_35817.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_35844.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_35846.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_3585.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_35883.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_3589.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_3592.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_35987.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_36004.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_36006.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_36016.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_36058.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_3609.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_36096.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_3613.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_36137.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_36321.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_36363.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_36381.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_36382.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_36388.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_36445.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_3645.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_36520.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_36529.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_36537.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_36545.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_36559.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_36564.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_3657.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_36582.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_36600.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_36603.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_36669.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_36687.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_36735.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_36750.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_36754.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_36802.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_3684.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_36862.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_36935.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_36945.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_36964.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_36994.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_37063.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_37070.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_37171.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_37175.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_37190.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_37294.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_37305.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_37423.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_37445.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_37465.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_37494.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_37495.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_37555.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_37563.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_37592.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_37623.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_37640.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_37683.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_37746.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_37841.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_37879.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_37888.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_37896.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_37900.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_37903.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_37942.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_3796.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_38023.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_38032.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_38073.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_38089.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_38099.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_38108.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_38153.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_38166.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_38217.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_38263.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_38278.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_38287.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_38300.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_38329.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_3835.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_3837.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_38400.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_38405.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_38420.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_38446.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_38467.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_3849.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_38541.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_3857.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_38606.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_38610.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_38650.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_38657.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_38698.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_38735.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_38757.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_38788.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_38804.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_38808.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_38823.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_38833.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_38890.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_38893.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_38925.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_38947.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_38957.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_38964.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_38979.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_39028.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_39035.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_39054.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_39056.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_39061.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_39153.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_3922.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_39222.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_39256.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_39288.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_39289.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_39307.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_3932.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_39334.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_39361.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_39363.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_39385.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_39492.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_39500.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_3951.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_39520.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_39527.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_39653.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_39690.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_39709.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_39781.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_39813.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_39821.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_39830.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_39863.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_39881.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_39892.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_39920.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_39946.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_3995.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_40008.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_40025.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_4003.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_40041.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_4007.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_40102.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_4013.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_40168.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_40203.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_40236.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_40255.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_4026.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_40311.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_40320.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_40327.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_4038.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_40416.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_40436.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_40447.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_40475.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_4051.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_4077.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_4094.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_4116.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_4127.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_413.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_4133.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_4205.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_4214.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_4256.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_4263.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_4292.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_4293.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_4303.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_4349.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_437.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_4394.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_4438.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_4448.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_4476.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_453.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_4534.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_4587.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_4592.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_4603.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_4626.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_4641.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_4656.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_4658.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_4717.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_4723.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_476.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_4809.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_4834.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_4843.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_4867.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_4873.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_4952.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_4998.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_5021.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_5025.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_5047.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_5150.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_5180.jpg
#   inflating: /content/satellite_dataset/data/cloudy/train_5206.jpg
# ...
#   inflating: /content/satellite_dataset/data/water/SeaLake_790.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_791.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_792.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_793.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_794.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_795.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_796.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_797.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_798.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_799.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_8.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_80.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_800.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_801.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_802.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_803.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_804.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_805.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_806.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_807.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_808.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_809.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_81.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_810.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_811.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_812.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_813.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_814.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_815.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_816.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_817.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_818.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_819.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_82.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_820.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_821.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_822.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_823.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_824.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_825.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_826.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_827.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_828.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_829.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_83.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_830.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_831.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_832.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_833.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_834.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_835.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_836.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_837.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_838.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_839.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_84.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_840.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_841.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_842.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_843.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_844.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_845.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_846.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_847.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_848.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_849.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_85.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_850.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_851.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_852.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_853.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_854.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_855.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_856.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_857.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_858.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_859.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_86.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_860.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_861.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_862.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_863.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_864.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_865.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_866.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_867.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_868.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_869.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_87.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_870.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_871.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_872.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_873.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_874.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_875.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_876.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_877.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_878.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_879.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_88.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_880.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_881.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_882.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_883.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_884.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_885.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_886.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_887.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_888.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_889.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_89.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_890.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_891.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_892.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_893.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_894.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_895.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_896.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_897.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_898.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_899.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_9.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_90.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_900.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_901.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_902.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_903.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_904.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_905.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_906.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_907.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_908.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_909.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_91.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_910.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_911.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_912.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_913.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_914.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_915.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_916.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_917.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_918.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_919.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_92.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_920.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_921.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_922.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_923.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_924.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_925.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_926.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_927.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_928.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_929.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_93.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_930.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_931.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_932.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_933.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_934.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_935.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_936.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_937.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_938.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_939.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_94.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_940.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_941.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_942.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_943.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_944.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_945.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_946.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_947.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_948.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_949.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_95.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_950.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_951.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_952.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_953.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_954.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_955.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_956.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_957.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_958.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_959.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_96.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_960.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_961.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_962.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_963.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_964.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_965.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_966.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_967.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_968.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_969.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_97.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_970.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_971.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_972.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_973.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_974.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_975.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_976.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_977.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_978.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_979.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_98.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_980.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_981.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_982.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_983.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_984.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_985.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_986.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_987.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_988.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_989.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_99.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_990.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_991.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_992.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_993.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_994.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_995.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_996.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_997.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_998.jpg
#   inflating: /content/satellite_dataset/data/water/SeaLake_999.jpg

# %% [markdown]
# ### Data Exploratory

# %%
# Mengenali Dataset
path = "/content/satellite_dataset/data"

classes = sorted([d for d in os.listdir(path) if os.path.isdir(os.path.join(path, d))])
print("Classes:", classes)

class_counts = {}
for cls in classes:
    cls_path = os.path.join(path, cls)
    images = [f for f in os.listdir(cls_path) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]
    class_counts[cls] = len(images)

data = pd.DataFrame(list(class_counts.items()), columns=['Class', 'Count'])
print(data)
# Out:
# Classes: ['cloudy', 'desert', 'green_area', 'water']
#         Class  Count
# 0      cloudy   1500
# 1      desert   1131
# 2  green_area   1500
# 3       water   1500

# %%
# Menampilkan Plot tiap Class
plt.figure(figsize=(10, 6))
sns.barplot(x='Class', y='Count', data=data, palette='pastel')
plt.title('Class Distribution')
plt.xlabel('Image of Satellite')
plt.ylabel('Number of Images')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-4-1318366b304a>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Class', y='Count', data=data, palette='pastel')

# %%
# Menampilkan visualisasi beberapa gambar dari tiap kelas
fig, axes = plt.subplots(nrows=1, ncols=4, figsize=(15, 10))
axes = axes.flatten()

for i, cls in enumerate(classes):
    if i >= 12:
        break
    img_path = os.path.join(path, cls, os.listdir(os.path.join(path, cls))[0])
    img = plt.imread(img_path)
    axes[i].imshow(img)
    axes[i].set_title(cls)
    axes[i].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Data Preprocessing

# %% [markdown]
# #### Split Dataset

# %%
# Path dataset yang digunakan
path = "/content/satellite_dataset/data"
new_path = "/content/satellite_dataset_split" # buat output

# Rasio pembagian data
train_ratio = 0.7  # 70% training
val_ratio = 0.15   # 15% validation
test_ratio = 0.15  # 15% testing

# Daftar kelas
classes = ['cloudy', 'desert', 'green_area', 'water']

# Membuat folder untuk output berdasarkan train, val, test
for split in ['train', 'val', 'test']:
    for cls in classes:
        os.makedirs(f"{new_path}/{split}/{cls}", exist_ok=True)

# %%
# Proses mengisi folder tiap kelas
for cls in classes:
    # ambil data dari base path
    cls_path = os.path.join(path, cls)
    images = [f for f in os.listdir(cls_path)
              if f.lower().endswith(('.png', '.jpg', '.jpeg'))]

    # mengambil gamabr random
    random.shuffle(images)

    # Menghitung jumlah setiap split
    total_images = len(images)
    train_count = int(total_images * train_ratio)
    val_count = int(total_images * val_ratio)
    test_count = total_images - train_count - val_count

    print(f"\nKelas {cls}: {total_images} gambar")
    print(f"  - Train: {train_count} gambar")
    print(f"  - Validation: {val_count} gambar")
    print(f"  - Test: {test_count} gambar")

    # Split data untuk train, val, test
    train_images = images[:train_count]
    val_images = images[train_count:train_count + val_count]
    test_images = images[train_count + val_count:]

    # Copy files random tadi ke folder yang sesuai
    for img in train_images:
        src = os.path.join(cls_path, img)
        dst = os.path.join(new_path, 'train', cls, img)
        shutil.copy2(src, dst)

    for img in val_images:
        src = os.path.join(cls_path, img)
        dst = os.path.join(new_path, 'val', cls, img)
        shutil.copy2(src, dst)

    for img in test_images:
        src = os.path.join(cls_path, img)
        dst = os.path.join(new_path, 'test', cls, img)
        shutil.copy2(src, dst)
# Out:
# Kelas cloudy: 1500 gambar
#   - Train: 1050 gambar
#   - Validation: 225 gambar
#   - Test: 225 gambar
#
# Kelas desert: 1131 gambar
#   - Train: 791 gambar
#   - Validation: 169 gambar
#   - Test: 171 gambar
#
# Kelas green_area: 1500 gambar
#   - Train: 1050 gambar
#   - Validation: 225 gambar
#   - Test: 225 gambar
#
# Kelas water: 1500 gambar
#   - Train: 1050 gambar
#   - Validation: 225 gambar
#   - Test: 225 gambar

# %%
# Verifikasi hasil copy data untuk split
for split in ['train', 'val', 'test']:
    print(f"\n{split.upper()}:")
    total_split = 0
    for cls in classes:
        count = len(os.listdir(f"{new_path}/{split}/{cls}"))
        print(f"  {cls}: {count} gambar")
        total_split += count
    print(f"  Total {split}: {total_split} gambar")
# Out:
# TRAIN:
#   cloudy: 1050 gambar
#   desert: 791 gambar
#   green_area: 1050 gambar
#   water: 1050 gambar
#   Total train: 3941 gambar
#
# VAL:
#   cloudy: 225 gambar
#   desert: 169 gambar
#   green_area: 225 gambar
#   water: 225 gambar
#   Total val: 844 gambar
#
# TEST:
#   cloudy: 225 gambar
#   desert: 171 gambar
#   green_area: 225 gambar
#   water: 225 gambar
#   Total test: 846 gambar

# %%
###
## Copy data Split dari Colab ke Drive
###
colab_data = '/content/satellite_dataset_split'

if os.path.exists(colab_data):
    # Cek isi data
    print("Isi data split:")
    for item in os.listdir(colab_data):
        item_path = os.path.join(colab_data, item)
        if os.path.isdir(item_path):
            count = len(os.listdir(item_path))
            print(f" file {item}/ - {count} subfolder")

    # Target lokasi untuk dipindah
    drive_path = '/content/drive/MyDrive/satellite_dataset_split'
    print(f"\nMemindahkan data ke Drive")

    # Copy data dari Colab ke Drive
    if not os.path.exists(drive_path):
        shutil.copytree(colab_data, drive_path)
        print("Data berhasil dipindah ke Google Drive!")
    else:
        print("Data sudah ada di Google Drive")

    # Verifikasi data sudah ada di Drive
    print(f"\n Lokasi data di Drive: {drive_path}")

    for item in os.listdir(drive_path):
        item_path = os.path.join(drive_path, item)
        if os.path.isdir(item_path):
            # Hitung jumlah gambar di setiap folder
            total_images = 0
            subfolders = os.listdir(item_path)
            print(f"  📁 {item}/")

            for subfolder in subfolders:
                subfolder_path = os.path.join(item_path, subfolder)
                if os.path.isdir(subfolder_path):
                    count = len([f for f in os.listdir(subfolder_path)
                               if f.lower().endswith(('.jpg', '.jpeg', '.png'))])
                    total_images += count
                    print(f"    📂 {subfolder}: {count} gambar")

            print(f"Total {item}: {total_images} gambar")

    print(f"Data sekarang tersimpan di Google Drive Anda")

else:
    print("Data split tidak ditemukan ")
# Out:
# Isi data split:
#  file val/ - 4 subfolder
#  file train/ - 4 subfolder
#  file test/ - 4 subfolder
#
# Memindahkan data ke Drive
# Data berhasil dipindah ke Google Drive!
#
#  Lokasi data di Drive: /content/drive/MyDrive/satellite_dataset_split
#   📁 val/
#     📂 green_area: 225 gambar
#     📂 water: 225 gambar
#     📂 desert: 169 gambar
#     📂 cloudy: 225 gambar
# Total val: 844 gambar
#   📁 train/
#     📂 green_area: 1050 gambar
#     📂 water: 1050 gambar
#     📂 desert: 791 gambar
#     📂 cloudy: 1050 gambar
# Total train: 3941 gambar
#   📁 test/
#     📂 green_area: 225 gambar
#     📂 water: 225 gambar
#     📂 desert: 171 gambar
#     📂 cloudy: 225 gambar
# Total test: 846 gambar
# Data sekarang tersimpan di Google Drive Anda

# %% [markdown]
# ## Modelling
# Membangun model CNN

# %%
###
## Setup Base Data Yang Digunakan
###

# Base Data menggunakan satellite_dataset_split
data_path = "/content/satellite_dataset_split"

# Setting random
tf.random.set_seed(42)

# Parameter gambar
IMG_SIZE = 224
BATCH_SIZE = 32
NUM_CLASSES = 4  # cloudy, desert, green_area, water

# Data generator untuk train
train_data = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    zoom_range=0.2
)

# Data Generator untuk validation dan test
val_test_data = ImageDataGenerator(rescale=1./255)


###
## Load Data Training, Testing, Validation
###

# Load data training
train_generator = train_data.flow_from_directory(
    f"{data_path}/train",
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True
)

# Load data validation
val_generator = val_test_data.flow_from_directory(
    f"{data_path}/val",
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

# Load data test
test_generator = val_test_data.flow_from_directory(
    f"{data_path}/test",
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

print("Kelas yang ditemukan:", train_generator.class_indices)
# Out:
# Found 3941 images belonging to 4 classes.
# Found 844 images belonging to 4 classes.
# Found 846 images belonging to 4 classes.
# Kelas yang ditemukan: {'cloudy': 0, 'desert': 1, 'green_area': 2, 'water': 3}

# %%
###
## Build Model CNN
###

model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(IMG_SIZE, IMG_SIZE, 3)),  # Conv1
    MaxPooling2D(2, 2),

    Conv2D(64, (3, 3), activation='relu'),     # Conv2
    MaxPooling2D(2, 2),

    Conv2D(128, (3, 3), activation='relu'),    # Conv3
    MaxPooling2D(2, 2),

    Conv2D(256, (3, 3), activation='relu'),    # Conv4
    MaxPooling2D(2, 2),

    Flatten(),  # Mengubah dari 2D ke 1D, diratain gitu (flat)

    # Fully Connected Layers
    Dense(512, activation='relu'),
    Dropout(0.5),  # Prevent overfitting
    Dense(256, activation='relu'),
    Dropout(0.3),

    Dense(NUM_CLASSES, activation='softmax')  # Output layer
])


###
## Compile dan Menampilkan Model CNN
###
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_4 (Conv2D)               │ (None, 222, 222, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 109, 109, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 54, 54, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 52, 52, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 26, 26, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 24, 24, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 12, 12, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 36864)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 512)            │    18,874,880 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 4)              │         1,028 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 19,395,652 (73.99 MB)
#  Trainable params: 19,395,652 (73.99 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Training Model

# %%
# Stop training jika model ditrain tidak improve
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True
)

# Mengurangi learning rate jika stuck
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.2,
    patience=3,
    min_lr=0.0001
)

callbacks = [early_stopping, reduce_lr]

# %%
EPOCHS = 20

history = model.fit(
    train_generator,
    epochs=EPOCHS,
    validation_data=val_generator,
    callbacks=callbacks,
    verbose=1
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/20
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 66s 449ms/step - accuracy: 0.5762 - loss: 0.7990 - val_accuracy: 0.6078 - val_loss: 0.6473 - learning_rate: 0.0010
# Epoch 2/20
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 49s 394ms/step - accuracy: 0.6789 - loss: 0.5830 - val_accuracy: 0.7334 - val_loss: 0.4755 - learning_rate: 0.0010
# Epoch 3/20
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 83s 403ms/step - accuracy: 0.7067 - loss: 0.5646 - val_accuracy: 0.8318 - val_loss: 0.3927 - learning_rate: 0.0010
# Epoch 4/20
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 50s 402ms/step - accuracy: 0.8220 - loss: 0.4225 - val_accuracy: 0.7358 - val_loss: 0.4968 - learning_rate: 0.0010
# Epoch 5/20
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 49s 392ms/step - accuracy: 0.8323 - loss: 0.3852 - val_accuracy: 0.8602 - val_loss: 0.3416 - learning_rate: 0.0010
# Epoch 6/20
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 50s 401ms/step - accuracy: 0.8192 - loss: 0.4219 - val_accuracy: 0.8412 - val_loss: 0.3164 - learning_rate: 0.0010
# Epoch 7/20
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 50s 400ms/step - accuracy: 0.8420 - loss: 0.3998 - val_accuracy: 0.8614 - val_loss: 0.3883 - learning_rate: 0.0010
# Epoch 8/20
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 50s 405ms/step - accuracy: 0.8682 - loss: 0.3130 - val_accuracy: 0.8661 - val_loss: 0.2954 - learning_rate: 0.0010
# Epoch 9/20
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 49s 391ms/step - accuracy: 0.8662 - loss: 0.3137 - val_accuracy: 0.8744 - val_loss: 0.2671 - learning_rate: 0.0010
# Epoch 10/20
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 50s 405ms/step - accuracy: 0.8619 - loss: 0.3225 - val_accuracy: 0.8661 - val_loss: 0.2797 - learning_rate: 0.0010
# Epoch 11/20
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 50s 405ms/step - accuracy: 0.8846 - loss: 0.2852 - val_accuracy: 0.7524 - val_loss: 0.7337 - learning_rate: 0.0010
# Epoch 12/20
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 50s 401ms/step - accuracy: 0.8060 - loss: 0.4396 - val_accuracy: 0.8566 - val_loss: 0.3483 - learning_rate: 0.0010
# Epoch 13/20
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 49s 393ms/step - accuracy: 0.8911 - loss: 0.2905 - val_accuracy: 0.9040 - val_loss: 0.2273 - learning_rate: 2.0000e-04
# Epoch 14/20
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 49s 394ms/step - accuracy: 0.9032 - loss: 0.2443 - val_accuracy: 0.9159 - val_loss: 0.1963 - learning_rate: 2.0000e-04
# Epoch 15/20
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 50s 402ms/step - accuracy: 0.9040 - loss: 0.2364 - val_accuracy: 0.9123 - val_loss: 0.2059 - learning_rate: 2.0000e-04
# Epoch 16/20
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 50s 402ms/step - accuracy: 0.9071 - loss: 0.2175 - val_accuracy: 0.9218 - val_loss: 0.2023 - learning_rate: 2.0000e-04
# Epoch 17/20
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 49s 396ms/step - accuracy: 0.8986 - loss: 0.2456 - val_accuracy: 0.9206 - val_loss: 0.1904 - learning_rate: 2.0000e-04
# Epoch 18/20
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 49s 396ms/step - accuracy: 0.9116 - loss: 0.2144 - val_accuracy: 0.9182 - val_loss: 0.1958 - learning_rate: 2.0000e-04
# Epoch 19/20
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 51s 408ms/step - accuracy: 0.9133 - loss: 0.2181 - val_accuracy: 0.9182 - val_loss: 0.1931 - learning_rate: 2.0000e-04
# Epoch 20/20
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 50s 405ms/step - accuracy: 0.9116 - loss: 0.2204 - val_accuracy: 0.9265 - val_loss: 0.1836 - learning_rate: 2.0000e-04

# %% [markdown]
# ## Evaluasi dan Visualisasi

# %%
# Menampilkan hasil akurasi model cnn
test_loss, test_accuracy = model.evaluate(test_generator, verbose=0)
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f} ({test_accuracy*100:.2f}%)")
# Out:
# Test Loss: 0.1575
# Test Accuracy: 0.9374 (93.74%)

# %%
# Menampilkan plot grafik training
def plot_training_history(history):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

    # Plot accuracy
    ax1.plot(history.history['accuracy'], label='Training Accuracy')
    ax1.plot(history.history['val_accuracy'], label='Validation Accuracy')
    ax1.set_title('Model Accuracy')
    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Accuracy')
    ax1.legend()
    ax1.grid(True)

    # Plot loss
    ax2.plot(history.history['loss'], label='Training Loss')
    ax2.plot(history.history['val_loss'], label='Validation Loss')
    ax2.set_title('Model Loss')
    ax2.set_xlabel('Epoch')
    ax2.set_ylabel('Loss')
    ax2.legend()
    ax2.grid(True)

    plt.tight_layout()
    plt.show()

plot_training_history(history)

# %% [markdown]
# ## Konversi Model

# %%
###
## SavedModel (.pb)
##

# Path untuk simpan model savedmodel
savedmodel = "/content/drive/MyDrive/saved_model"

# Export ke SavedModel
tf.saved_model.save(model, savedmodel)

print(f"SavedModel tersimpan di: {savedmodel}")
print(f"Ukuran folder: {sum(os.path.getsize(os.path.join(dirpath, filename)) for dirpath, dirnames, filenames in os.walk(savedmodel) for filename in filenames) / (1024*1024):.2f} MB")
# Out:
# SavedModel tersimpan di: /content/drive/MyDrive/saved_model
# Ukuran folder: 222.14 MB

# %%
###
## TF-Lite Model
##

# Base path untuk simpan model tflite
base_path = '/content/drive/MyDrive/tflite'
os.makedirs(base_path, exist_ok=True)  # Buat folder jika belum ada

# Konversi model ke TFLite
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_model = converter.convert()

# Menyimpan file model .tflite
tflite_path = os.path.join(base_path, 'model.tflite')
with open(tflite_path, 'wb') as f:
    f.write(tflite_model)
print(f"Model TFLite tersimpan di: {tflite_path}")

# Daftar Class
classes = ['cloudy', 'desert', 'green_area', 'water']

# Label path Class
label_path = os.path.join(base_path, 'label.txt')
with open(label_path, 'w') as f:
    for label in classes:
        f.write(label + '\n')
print(f"Label file tersimpan di: {label_path}")
# Out:
# Saved artifact at '/tmp/tmp_kdk08ed'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor_15')
# Output Type:
#   TensorSpec(shape=(None, 4), dtype=tf.float32, name=None)
# Captures:
#   135984219595280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135984219587792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135984219593552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135984219592400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135984219587984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135984219600080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135984219599504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135984219600848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135984219600272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135984219601616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135984219601040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135984219602384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135984219601808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135984219602576: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Model TFLite tersimpan di: /content/drive/MyDrive/tflite/model.tflite
# Label file tersimpan di: /content/drive/MyDrive/tflite/label.txt

# %%
###
## TFJS Model
##

# Base path untuk menyimpan model
tfjs_path = '/content/drive/MyDrive/model_tfjs'
os.makedirs(tfjs_path, exist_ok=True)

# Simpan model ke format TFJS
tfjs.converters.save_keras_model(model, tfjs_path)

print(f"Model berhasil disimpan ke format TensorFlow.js di: {tfjs_path}")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# failed to lookup keras version from the file,
#     this is likely a weight only file
# Model berhasil disimpan ke format TensorFlow.js di: /content/drive/MyDrive/model_tfjs

# %%
# Menyimpan model .keras untuk inference
keras_path = '/content/drive/MyDrive/satelite.keras'
model.save(keras_path)
print(f"Model berhasil disimpan di: {keras_path}")
# Out:
# Model berhasil disimpan di: /content/drive/MyDrive/satelite.keras

# %% [markdown]
# ## Inference (Optional)

# %%
model = tf.keras.models.load_model('/content/drive/MyDrive/Submission/Deep Learning/Image Classification/satelite.keras')

# Load image
img_path = '/content/drive/MyDrive/Submission/Deep Learning/Image Classification/satellite_dataset_split/test/green_area/Forest_1777.jpg'

img = image.load_img(img_path, target_size=(224, 224))
plt.imshow(img)
plt.axis('off')
plt.title("Input Image")
plt.show()

# Preprocessing gambar
img_array = image.img_to_array(img) / 255.0
img_array = np.expand_dims(img_array, axis=0)

# Lakukan prediksi
prediction = model.predict(img_array)

# Ambil kelas prediksi
class_labels = ['cloudy', 'desert', 'green_area', 'water']
predicted_index = np.argmax(prediction)
predicted_label = class_labels[predicted_index]

# Tampilkan hasil
print("Prediction score:", prediction)
print("Predicted class:", predicted_label)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Prediction score: [[7.0972671e-04 1.2780077e-05 7.0499152e-01 2.9428595e-01]]
# Predicted class: green_area

# %%
model = tf.keras.models.load_model('/content/drive/MyDrive/Submission/Deep Learning/Image Classification/satelite.keras')

# Load image
img_path = '/content/drive/MyDrive/Submission/Deep Learning/Image Classification/satellite_dataset_split/val/cloudy/train_19442.jpg'

img = image.load_img(img_path, target_size=(224, 224))
plt.imshow(img)
plt.axis('off')
plt.title("Input Image")
plt.show()

# Preprocessing gambar
img_array = image.img_to_array(img) / 255.0
img_array = np.expand_dims(img_array, axis=0)

# Lakukan prediksi
prediction = model.predict(img_array)

# Ambil kelas prediksi
class_labels = ['cloudy', 'desert', 'green_area', 'water']
predicted_index = np.argmax(prediction)
predicted_label = class_labels[predicted_index]

# Tampilkan hasil
print("Prediction score:", prediction)
print("Predicted class:", predicted_label)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 794ms/step
# Prediction score: [[9.9456441e-01 5.0357003e-03 1.4361348e-06 3.9845449e-04]]
# Predicted class: cloudy
